# %% [markdown]
# <h2>Chapter One: AI Foundations</h2>

# %% [markdown]
# #### <h1>Section 1.4 Artificial Intelligence and Machine Learning</h1>

# %% [markdown]
# <h4>For today, Tuesday, January 31:</h4>
# <ul>
#     <li>The quiz on chapter three - both individual and team.</li>
#     <li>Team exercises based upon our readings to date.</li>
# </ul>

# %% [markdown]
# If you're not on a team, please come see me.

# %% [markdown]
# <h3>Accessing Brightspace</h3>
# <a href="https://brighspace.albany.edu">brightspace.albany.edu</a>

# %% [markdown]
# <h2>Extra Credit Events</h2>
# There are already two extra credit events available.
# <ul>
# <li>Writers Institute Talk by author Andy Greenberg on his new book <i>Tracers in the Dark: The Global Hunt for the Crime Lords of Cryptocurrency</i>
#     <a href="https://www.nyswritersinstitute.org/andy-greenberg">Link to the event</a></li>
# <li>A Panel Discussion on ChatGPT.</li>
# </ul>

# %% [markdown]
# ![ChatGPT%20Flyer%20v23%2001%2022.jpg](attachment:ChatGPT%20Flyer%20v23%2001%2022.jpg)

# %% [markdown]
# <h2>Reading: Chapter Three</h2>
# <em>Machine Learning: Mining Insights from Data</em>
#
# <p>The Stitch Fix example: using the machine learning to complement the abilities of the human stylists.
#
# <p>Arthur Samuels and Checkers
# <ul>
#             <li>AT IBM created a checkers palying program that learned.</li>
#         <li>The first ML program</li>
#         <li>"A computer could learn and improve by processing data without having to be explicitly programmed."</li>
#         <li>Statistics</li>
#         <li>Probability</li>
#             <li>Trained to make predictions.</li>
#             <li> In contrast to normal computer programs (e.g .expert systems) that are lists of commands/rules.</li>
# </ul>
#         <p>The hot dog recognizer anecdote.

# %% [markdown]
# <h3>The Math</h3>
# <p>We will dig in on this later
# The topics:<ul>
#     <li>Standard Deviation</li>
#     <li>The Normal Distribution</li>
#     <li>Correlation</li>
#     </ul>

# %% [markdown]
# <h4>Feature Extraction</h4>
# This is an important topic in ML.
# [Ask the class]

# %% [markdown]
# <h4>Some Examples</h4>
# What can you do with Machine Learning:
# <ul>
#     <li>Predictive Maintenance</li>
#     <li>Recruiting Employees</li>
#     <li>Customer Experience</li>
#     <li>Finance</li>
#     <li>Chatbots for various applications</li>
#     <li>Dating</li>
#     </ul>

# %% [markdown]
# <h3>The Machine Learning Life Cycle</h3>
# Analogous to the software development life cycle.
# <p>A kind of specific project management.
# <p>The Machine Learning Process
# <ol>
#     <li>Get and prepare your data</li>
#     <ul><li>Gather the data</li>
#         <li>Clean the data</li>
#         <li>Test/check the data for completeness, bias, etc.</li>
#     </ul>
#     <li>Choose a model/algorithm</li>
#     <li>Train the model</li>
#     <ul><li>Pick a training/testing strategy to avoid overfitting.</li>
#         <li>Divide the dataset into training, testing, evaluation, etc.</li>
#         <li>Train the system on the data</li>
#         <ul><li>Monitoring for learning, overfitting, etc.</li>
#         </ul>
#     </ul>
#     <li>Evaluate the model</li>
#     <li>Fine tune the model</li>
# </ol>

# %% [markdown]
# <h3>Types of Machine Learning</h3>
# The main different types of machine learning:
# <ul>
#     <li>Supervised Learning</li>
#     <li>Unsupervised Learning</li>
#     <li>Reinforcement Learning</li>
#     <li>Semi-supervised Learning</li>
#     </ul>

# %% [markdown]
# <h3>Some Common Machine Learning Algorithms</h3>
# Some widely used/cited <em>alogrithms</em>
# <ul>
#     <li>Naive Bayes classifier</li>
#     <li>K-nearest neighbor classifier</li>
#     <li>Linear Regression</li>
#     <ul><li>A baseline method that others are often compared to or based on</li></ul>
#     <li>Decision Trees</li>
#     <li>Ensemble Methods</li>
#     <ul><li>Basically, using multiple models and combining their outputs/predictions.</li></ul>
#     <li>K-means clustering</li>

# %% [markdown]
# <h2>Team Exercise</h2>
# In the Introduction, the author gives two examples of companies that use AI/ML, Uber and McDonalds. Starting from what Taulli says, discuss the following:
# <p>The two cases seem to be different uses of AI/ML technology. Examine the two cases, starting with Taulli, but seasrching the web as necessary (cite your sources you use!).
#     Answer the following questions as best you can:<ul>
#         <li>Describe the two AI/ML use cases.</li>
#         <li>What do they have in common?</li>
#         <li>How are they different?</li>
#         <li> Is one or the other more of an actual "artificial intelligence" application? Or are both? Neither?</li>
#         </ul>
#         For each of these justify your answer.
#         Please submit on Brightspace:
#         <ul>
#     <li>The names of the team members</li>
#     <li>Your answers to the above.</li>
#     <ul>

# %% [markdown]
# <h3>Preparing for Upcoming Classes</h3>
# <!--
# <h4>For next class meeting (Tuesday, January 24)</h4>
# <ul>
#     <li>Get the text</li>
#     <li>Read the Forward, Introduction, and Chapter One</li>
#     <li>Read the online article <i>Introduction to Artificial Intelligence</i> <a href="https://www.red-gate.com/simple-talk/development/data-science-development/introduction-to-artificial-intelligence/">Link to the article</a></li>
#      </ul>
# -->

# %% [markdown]
# <h4>For Thursday, February 2:</h4>
# <ul>
#     <li>Read Chapter Four in the Text</li>
#     <li>There will be a short quiz on Chapter Four.<ul><li>(Individual and team)</li></ul></li>
#     <li>And team exercises.</li>
# </ul>

# %% [markdown]
# <h4>For Tuesday, February 7:</h4>
# <ul>
#     <li>Team exercises based upon our readings to date.</li>
# </ul>
#
# <h4>For Thursday, February 9:</h4>
# <ul>
#     <li>Read Chapter EIght in the Text</li>
#     <li>There will be a short quiz on Chapter Eight.<ul><li>(Individual and team)</li></ul></li>
#     <li>And exercises.</li>
# </ul>
#
# <h4>For Tuesday, February 14:</h4>
# <ul>
#     <li>Team exercises based upon our readings to date.</li>
# </ul>

# %% [markdown]
# <!--
# <h1>section 1.3: Artficial Intelligence and Machine Learning</h1>
# -->

# %% [markdown]
# <!--
# <h2>Readings: Text Chapter Three</h2>
# -->

# %% [markdown]
# </body>
