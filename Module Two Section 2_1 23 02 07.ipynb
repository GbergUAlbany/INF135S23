# %% [markdown]
# <h1>Module Two: AI Foundations</h1>

# %% [markdown]
# ## <h2>Section 2.1: Machine Learning</h2>

# %% [markdown]
# <h3>Administrative and logistical matters</h3>
# <h4>Accessing Brightspace</h4>
# <a href="https://brighspace.albany.edu">brightspace.albany.edu</a>
# <h4>Teams</h4>
# If you're not on a team, please come see me.

# %% [markdown]
# <h2>Extra Credit Events</h2>
# There have already been two extra credit events available.
# <ul>
# <li>Writers Institute Talk by author Andy Greenberg on his new book <i>Tracers in the Dark: The Global Hunt for the Crime Lords of Cryptocurrency</i>
#     <a href="https://www.nyswritersinstitute.org/andy-greenberg">Link to the event</a></li>
# <li>A Panel Discussion on ChatGPT.</li>
# </ul>
# We are adding a third - a showing of the file <em>Coded Bias</em> the evening of February 28th.

# %% [markdown]
# ![CODED%20BIAS%200228.png](attachment:CODED%20BIAS%200228.png)

# %% [markdown]
# ![Semirah%20dolan.jpg](attachment:Semirah%20dolan.jpg)

# %% [markdown]
# <h3>Today's Class</h3>
#
# <h4>For Tuesday, February 7:</h4>
# <ul>
#     <li>Go over Thursday's quiz.</li>
#     <li>Go over chapter four.</li>
#     <li>Team exercises based upon our readings to date.</li>
# </ul>

# %% [markdown]
# <h3>Go Over Thursday's Quiz</h3>

# %% [markdown]
# <h2>Reading: Chapter Four</h2>
# <em>Deep Learning: The Revolution in AI</em>

# %% [markdown]
# <h3>ImageNet and Deep Learning</h3>
# Fei-Fei Lei and the creation of Imagenet.
# <ul>
# <li> A platform for creating and testing AI models.</li>
# <li>Used Amazon's Mechanical Turk </li>
#     <li>By 2010 it contained 3.2 million images.</li>
#     <li>The images were classified across 5,200 different categories.</li>
#     <li>It received an initially lackluster response.</li>
#     <li>In 2012 she organized a contest for AI systems to compete to correctly classify the images in Imagenet.</li>
#     <li>A team led by Geoff Hinton (U. Toronto) won the contest.</li>
#     <ul>
#         <li>They beat the next best team by 10.8%.</li>
#     </ul>
#     <li>Hinton's team used a ML approach called <em>Deep Learning</em></li>
#     </ul>

# %% [markdown]
# <p>Since then Deep Learing has continued to improve. To the point where it does better than humans on ImageNet classification.
# <p>The book calls Deep Learning the "hottest area in AI."
#     <p>Probablby still true, even with ChatGPt, since ChatGPT uses Deep Learning.

# %% [markdown]
# <h3>Artificial Neural Networks (ANNs)</h3>

# %% [markdown]
# ![1%2049fUvSpyAnHCR82alSd68w.png](attachment:1%2049fUvSpyAnHCR82alSd68w.png)

# %% [markdown]
# An ANN has:
# <ul>
#     <li>An <em>input layer</em></li>
#     <li>One of more <em>hidden layers</em></li>
#     <li>An <em>output layer</em></li>
#     </ul>

# %% [markdown]
# <h4>How a backprop ANN works</h4>
# <ul>
#     <li>Input presented to the model</li>
#     <li>The values are calculated forward through the model to the output</li>
#     <li>If we're learning, we estimate the <em>error</em> - the difference between the actual and calculated/predicted output.</li>
#     <ul>
#         <li>Activation Functions</li>
#     </ul>
#     <li>We propagate the error backwards through the model, and as part of this we change the weights to try and reduce the error from this particular input.</li>
#     </ul>
# <p> We repeat this process, first with each different piece of input data we have.
#     <p>Then we show the whole data set over and over either until it performs to our satisfaction, or we decide it won't learn sufficiently, and we call it quits.

# %% [markdown]
# <h4>Recurrent Neural Networks</h4>
# <p>A <em>recurrent neural network</em> (RNN) is one where the network knows what inputs it has seen before.
# <p>(A normal ANN has no idea of anything but the current input.)
# <p>In traditional RNNs:
#     <ul>
#         <li>The error signal tends to get weaker and weaker as subsequent inputs are seen.</li>
#         <li>It is hard for an RNN to keep track of information/signal from  far away in a sequence of inputs (e.g. in a long paragraph, or a protein sequence).</li>
# </ul>
# <p> Newer models, <em>Transformers</em> have overcome many of these difficulties and form the basis for many of the state of the art AI/ML models (e.g. ChatGPT).

# %% [markdown]
# ![ANN-RNN%20Architecture.jpg](attachment:ANN-RNN%20Architecture.jpg)

# %% [markdown]
# <p>

# %% [markdown]
# ![RNN%20Architecture.jpg](attachment:RNN%20Architecture.jpg)

# %% [markdown]
# <h4>Convolutional Neural Networks</h4>
# <p>In traditional ANNs the architecture is relatively simple:
#     <ul>
#         <li>All the hidden layers are the same, except for number of units</li>
#         <li>All units in a layer are connected to all the units in the previous and following layer.</li>
#         </ul>
# <p>But this was considered to limit the abilities of the ANNs to learn more complex problems.
#     <ul>
#         <li>The model could easily <em>overfit</em> to the training data.</li>
#         <li>These models had problems with what should be minor detils in an input (e.g. in an image, where in the image the item of interest is).</li>
#         <li>As the models grow larger, this complete interconnection can result in large amounts of computation for all the weights between the layers.</li>
#         </ul>
# <p>In 1998, Yann LeCun published his first work on <em>Convolutional Neural Networks</em> (CNNs).
#     <p>LeCun was inspired work on the neurons in the visual cortex.
# <p>A CNN has different kinds of layers, and not all are completely connected:
#     <ul>
#         <li><em>Convolutional layer</em> - a layer that examines (/filters/scans) a part of the image (e.g., a 5x5 pixel segment).</li>
#         <li>The convolutional layers learn the features of the image (e.g. the lines, edges, shapes) that make up the features relevant to learn the problem the model is trying to solve)</li>
#         <li>Subsequent layers take these features and try and combine them to detect the presence or absence of higher level structures shapes, objects, etc.</li>
#         <li>These are then <em>pooled</em> as input to the final hidden and output layers that are able to predict the problem the model is designed to solve.</li>
#         </ul>

# %% [markdown]
# ![CNN.jpg](attachment:CNN.jpg)

# %% [markdown]
# <h4>Deep Learing Examples</h4>
# Some examples models/problems:
# <ul>
#     <li>Detecting Alzheimers Disease</li>
#     <li>Energy Efficiency</li>
#     <li>Earthquake detection</li>
#     <li>Analyzing radioloogical images</li>
#     </ul>

# %% [markdown]
# <h4>Hardware for Deep Learning</h4>
# In the same sense that GPUs have helped speed up computing for traditional machine learning, for Deep Learning additional hardware has been developed.
# <ul>
#     <li>Google TPUs</li>
#     <li>Amazon Inferentia</li>
#     <li>Intel Nervana</li>
#     <li>Others</li>
#     </ul>

# %% [markdown]
# <h3>Deep Learning</h3>
# <p>Deep Learning is based on supervised learning, specifically error backpropagation <em>artificial neural networks</em> (ANNs).
# <p>Normal Supervised Learning (e.g., ANNs):
#     <ul>
#         <li>Requires you to label data (e.g.,the images) you want to classify</li>
#         <li>For all but simple problems, you need to do feature extraction on the images and provide those features as part of the imput.</li>
#         </ul>
# In contrast to Deep Learning:
#    <ul>
#     <li>It still needs the images to be labeled with the category you're trying to classify/predict</li>
#     <ul>
#         <li>But, wait - we may be able to get around that partially with <em>semi-supervised learning</em> which we'll discuss later.
#     </ul>
#     <li>We don't need to do feature extraction or add those extracted features to the input.</li>
#     </ul>
#
# <p>A Deep Learning system has several important differences from an ANN ML model.
#     <ul>
#         <li> It has more <em>layers</em>.</li>
#         <li>You typically use a lot more data than with an ANN. </li>

# %% [markdown]
# <h4>Uses of Deep Learning</h4>
# Ok, when do we use Deep Learning?
# <p>Some considerations:
#     <ul>
#         <li>When it is worthwhile to collect the large amount of data a Deep Learning model needs</li>
#         <li>When it is worthwhile to use the large amount of computation necessary to train a Deep Learning model.</li>
#         <li>You might consider using cheaper, simpler ML models (e.g. ANNs) first, and then move to Deep Learing if those don't solve the problem.</li>
#         <li>Sometimes even a Deep Learning model won't be able to solve a problem.</li>
#         <li>For any kind of ML model, make sure your data is good (e.g., representative, covers all cases)</li>
#         </ul>

# %% [markdown]
# <h4>Some things to think about</h4>
# <ul>
#     <li>Gary Marcus worries that Deep Learning does not get us to <em>Artificial General Intelligence.</em></li>
#     <li>Deep Learning (as well as most ANNs and other ML models) tend to be <em>black boxes</em>/<em>opaque</em>. That is, it is hard to understand exactly how they solve their problems even when they work. To address this there is research going on in</li>
#     <ul>
#         <li>Explainable machine learning</li>
#         <li>Trustworthy machine learning</li>
#     </ul>
#     <li>It takes <em>lots</em> of data to feed Deep Learning models.</li>
#     <li>Some kinds of reasoning that deep learning does not (yet?) do well:</li>
#         <ul>
#     <li>Hierarchical structure</li>
#             <li>Open ended inference</li>
#             <li>Conceptual thinking</li>
#             <li>Common sense</li>
#             <li>Causation</li>
#             <li>Prior Knowledge</li>
#             <li>Static - I think this one may have been overcome (cf. work by DeepMind)</li>
#             <li>The butterfly effect</li>
#             <li>Overfitting</li>
#     </ul>
# </ul>

# %% [markdown]
# <h3>Generative Adversarial Networks (GANs)</h3>
# <p>Invented by Ian Goodfellow
# <p>Goodfellow also one of the best technical textbooks on machine learning, <em>Deep Learning</em>
# <p>A GAN has:
#     <ul>
#         <li>A <em>Generator</em> - creates (generates) possible examples of the problem of interest (e.g. lifelike cat pictures)</li>
#         <li>A <em>Discriminator</em> - evaluates the generated examples to determine which are good and not.</li>
#         <li>The model makes <em>Adjustments</em> - The two parts of the GAN keep learning, hopefully eventually creating realistic images, etc. generation.</li>
#             </ul>
# <p>GAN-related generative models underly all of the current technology that generates text (ChatGPY), images (DALL-E), etc.
# <p>It also underlies <em>Deepfakes</em>

# %% [markdown]
# ![index.png](attachment:index.png)

# %% [markdown]
# <h2>Team Exercise</h2>
#
# <p>I want your team to create a system to detect how many cars cross a local bridge. The system must recognize a car, and which direction it's going. If there is a car detected, the output of the ML system is combined with a date stamp (e.g. something to the effect of "A car was detected traveling west-bound at 1:34 PM on Wednesday, Feburuary 22, 2023.") and this is sent to a database of some kind.
#
# <p>For this exercise, you should try and specify:
# <ul>
#     <li>What kind of machine learning model would you use?
#         <ul>
#             <li>Justify your answer</li>
#             <li>Discuss why you didn't choose some of the other possible models.
#         </ul>
#     <li>What kind of data would you need for this project?</li>
#         <ul>
#             <li>What difficulties would you anticipate with the data?</li>
#             <li>Are there any aspects of this data that you need to be careful about?</li>
#       </ul>
#     <li>Are there any other considerations in solving this problem?</li>
# </ul>
#
# <p>No fair using ChatGPT, or some other holistic approach to having the internet, etc. solve the problem for you. You can look up specifics, but that's it. The ideas and approaches need to be your own. Be sure to cite your sources!
#
# <p>Please submit on Brightspace:
#         <ul>
#     <li>The names of the team members present.</li>
#     <li>Your answers to the above.</li>
#     <ul>

# %% [markdown]
# <h3>Preparing for Upcoming Classes</h3>
# <!--
# <h4>For next class meeting (Tuesday, January 24)</h4>
# <ul>
#     <li>Get the text</li>
#     <li>Read the Forward, Introduction, and Chapter One</li>
#     <li>Read the online article <i>Introduction to Artificial Intelligence</i> <a href="https://www.red-gate.com/simple-talk/development/data-science-development/introduction-to-artificial-intelligence/">Link to the article</a></li>
#      </ul>
# -->

# %% [markdown]
# <h4>For Thursday, February 9:</h4>
# <ul>
#     <li>Read Chapter Eight in the Text</li>
#     <li>There will be a short quiz on Chapter Eight.<ul><li>(Individual and team)</li></ul></li>
#     <li>And exercises.</li>
# </ul>
#
# <h4>For Tuesday, February 14:</h4>
# <ul>
#     <li>Team exercises based upon our readings to date.</li>
# </ul>

# %% [markdown]
# <!--
# <h1>section 1.3: Artficial Intelligence and Machine Learning</h1>
# -->

# %% [markdown]
# <!--
# <h2>Readings: Text Chapter Three</h2>
# -->

# %% [markdown]
# </body>
